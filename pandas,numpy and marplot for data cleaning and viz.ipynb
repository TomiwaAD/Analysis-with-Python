# %%
#importing necessary libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading excel file
df_results = pd.read_excel('/Users/tomiwaadewuni/Downloads/StudentsPerformance.xlsx')

# %%
#Showing the first 10 rows of the dataframe
df_results.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
#showing the last 10 rows of the dataframe
df_results.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 990               completed          86             81             75
# ...

# %%
 # delecting the none applicable columns
print('df_results')
# Out:
# df_results

# %%
df_results
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#selecting the useful columns and droping the rest.df
df_result=df_results[['gender','race/ethnicity','parental level of education','lunch','test preparation course','math score','reading score','writing score']]

# %%
#describing the entire dataset
df_result.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#to display dataframe shape attributes
df_result.shape
# Out:
# (1000, 8)

# %%
# to display all the rows of dataframe
pd.set_option('display.max_row',1000)
df_result
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
# counting gender row by category
df_gender=df_result['gender'].value_counts()

# %%
#count of elements in 'parantal level of education' by category
df_Parent=df_result['parental level of education'].value_counts()

# %%
# counting race/ethnicity row by category
df_race=df_result['race/ethnicity'].value_counts()

# %%
#count of elements in 'lunch' by category
df_lunch=df_result['lunch'].value_counts()

# %%
#sorting multiple columns
df_results=df_result.sort_values(['math score','reading score','writing score'])

# %%
df_race.plot(kind='line', xlabel='ethnicity', ylabel='count of students',
            title='students ethnicity')
#save plot
plt.savefig('my_test.png')
#show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_Parent.plot(kind='bar', xlabel='ethnicity', ylabel='count of students',
            title='students ethnicity')
#save plot
plt.savefig('my_test.png')
#show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_lunch.plot(kind='pie')
#save plot
plt.savefig('my_test.png')
#show plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#export to MS Excel
df_race.to_excel('/Users/tomiwaadewuni/Downloads/StudentsPerformance.xlsx')
